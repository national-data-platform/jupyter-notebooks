# %% [markdown]
# <div style="display: flex; justify-content: space-between; align-items: center; margin-bottom: 20px;">
#     <div style="flex: 0 0 auto; margin-left: 0; margin-bottom: 0; width: 300px; height: 200px; ">
#         <img src="https://www.anl.gov/sites/www/files/2020-05/SAGE-image.jpg" alt="SAGE Logo"/>
#     </div>
#     <div style="flex: 0 0 auto; margin-left: auto; margin-bottom: 0;">
#         <img src="https://nairrpilot.org/app/site/media/ndp.jpg" alt="NDP Logo" width="200"/>
#     </div>
# </div>

# %% [markdown]
# # SciDX SAGE Streaming Tutorial
#
# In this tutorial, we will stream and manage data from **SAGE sensors** using the **SciDX platform**. You will learn to how to register, filter, and process real-time data streams efficiently.
#
# This tutorial covers:
#
# 1. **Registering SAGE sensor data streams** with the sciDX API.
# 2. **Applying filters** to customize data streams for specific needs.
# 3. **Consuming and visualizing real-time data** to analyze sensor data dynamically.

# %% [markdown]
# ### Initilizing

# %% [markdown]
# ## Step 1: Setting Up the sciDX Client and Logging In
#
# To start, we’ll import the necessary modules, set up our API URL and credentials, and then initialize the sciDX client. This client will allow us to interact with the sciDX platform for registering and consuming sensor data.

# %%
# Import the sciDX client and demo-specific modules
from scidx.client import sciDXClient
from sage_demo import sensor_data, filters, SageDataProcessing, plot_temp_alerts

# Define URL of the sciDX API
API_URL = "https://vdc-192.chpc.utah.edu/scidx"

# Set user credentials
username = "demo@sage.com"
password = "sage"

# %%
# Initialize the sciDXClient with the API URL
client = sciDXClient(API_URL)

# Log in to the sciDX platform using the provided username and password
client.login(username, password)

# %% [markdown]
# ## Step 2: Registering BME280 Sensor Data from multiple SAGE nodes
#
# In this step, we’ll register data streams from BME280 sensors, specifically for temperature, pressure, and humidity, into sciDX. Each sensor’s data will be registered as a unique resource with its respective URL.
#
# ### Data Streams
# - **Temperature**
# - **Pressure**
# - **Humidity**

# %%
# Register each sensor data stream from the `sensor_data` list
for sensor in sensor_data:
    response = client.register_url(sensor)
    print(f"{sensor['resource_title']} registered successfully with ID: {response['id']}")
# Out:
# BME280 Temperature registered successfully with ID: 6e5eb6e0-7050-4610-9257-302566316696
# BME280 Pressure registered successfully with ID: 3354de76-4fc4-48fb-bc8e-1f462d823d70
# BME280 Humidity registered successfully with ID: 9aebd5f8-8dc4-49fb-b380-eb7536dcbb13

# %% [markdown]
# ## Step 3: Searching for Registered BME280 Sensor Data
#
# With the BME280 sensor data registered, we can now search for these resources on the sciDX platform. Using the prefix `sage_demo_bme280`, we’ll retrieve all datasets related to this sensor.

# %%
# Search for all registered BME280 sensor datasets
search_results = client.search_resource(search_term="sage_demo_bme280")
print(f"Number of datasets found: {len(search_results)}")
# Out:
# Number of datasets found: 3

# %% [markdown]
# ## Step 4: Creating and Filtering a Data Stream Using sciDX Filtering Capabilities
#
# In this step, we’ll create a Kafka data stream on sciDX with filters to select specific data and apply custom alerts. Here’s how the data is filtered and transformed:
#
# - **State Selection**: Filters to only include data from California, Montana, Oregon, North Dakota, Michigan, and Illinois.
# - **Data Mapping**: Maps sensor readings to temperature, pressure, and humidity fields.
# - **State Assignment**: Associates each sensor with its corresponding state name.
# - **Conditional Alerts**:
#   - **Heatwave Alert**: Activates if temperature > 35°C or humidity < 25%.
#   - **State-Specific Alerts**: Certain states have unique temperature thresholds that will trigger alerts:
#     - Montana: Temperature > 40°C
#     - Oregon: Temperature > 30°C
#   - **Pressure Alert**: Activates if pressure exceeds 101,000 Pa.
# - **Pressure Adjustment**: For certain temperature alerts, reduces pressure readings by 5%.
#
# These filters give us a tailored view of the data, isolating specific conditions and providing custom alerts.

# %%
# Create the Kafka stream using sciDXClient with specified filters for SAGE data
stream_response = client.create_kafka_stream(
    keywords=["sage_demo"], 
    filter_semantics=filters
)

print("Stream Created. Topic:", stream_response['topic'])
# Out:
# Stream Created. Topic: data_stream_604e99e6-a9a6-4cd1-9c47-d55e3b92eee0_1

# %% [markdown]
# ## Step 5: Consuming the Filtered Stream Data
#
# With the Kafka stream created and filters applied, we can now start consuming the filtered data in real time. Our consumer will listen continuously to incoming messages and populate a dynamic DataFrame as new data arrives.

# %%
# Start consuming Kafka messages from the created topic
consumer = client.consume_kafka_messages(topic=stream_response['topic'])

# %% [markdown]
# #### Viewing a Simple Data Summary
#
# We can view a summary of the latest data received, focusing on selected columns. The summary will also show the current total rows and columns.

# %%
# Display a summary of the raw received data
consumer.summary(['timestamp', 'state', 'alert', 'temperature', 'humidity', 'pressure'])
# Out:
# <style type="text/css">
# #T_ca0dc th {
#   font-weight: bold;
#   background-color: #e8f4f8;
#   text-align: center;
# }
# #T_ca0dc td {
#   text-align: center;
#   padding: 6px;
#   background-color: #f7fbfc;
# }
# </style>
# <table id="T_ca0dc">
#   <caption>Latest Data Row</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_ca0dc_level0_col0" class="col_heading level0 col0" >timestamp</th>
#       <th id="T_ca0dc_level0_col1" class="col_heading level0 col1" >state</th>
#       <th id="T_ca0dc_level0_col2" class="col_heading level0 col2" >alert</th>
#       <th id="T_ca0dc_level0_col3" class="col_heading level0 col3" >temperature</th>
#       <th id="T_ca0dc_level0_col4" class="col_heading level0 col4" >humidity</th>
#       <th id="T_ca0dc_level0_col5" class="col_heading level0 col5" >pressure</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ca0dc_level0_row0" class="row_heading level0 row0" >2841</th>
#       <td id="T_ca0dc_row0_col0" class="data row0 col0" >['2024-11-12T19:44:45.347679417Z', '2024-11-12T19:44:51.650720965Z']</td>
#       <td id="T_ca0dc_row0_col1" class="data row0 col1" >['Montana', 'California']</td>
#       <td id="T_ca0dc_row0_col2" class="data row0 col2" >['None', 'None']</td>
#       <td id="T_ca0dc_row0_col3" class="data row0 col3" >[24.14, 34.95]</td>
#       <td id="T_ca0dc_row0_col4" class="data row0 col4" >N/A</td>
#       <td id="T_ca0dc_row0_col5" class="data row0 col5" >N/A</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_02ddd th {
#   font-weight: bold;
#   background-color: #f2f2f2;
# }
# #T_02ddd td {
#   text-align: center;
#   padding: 6px;
# }
# </style>
# <table id="T_02ddd">
#   <caption>Summary Statistics</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_02ddd_level0_col0" class="col_heading level0 col0" >Total Rows</th>
#       <th id="T_02ddd_level0_col1" class="col_heading level0 col1" >Total Columns</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_02ddd_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_02ddd_row0_col0" class="data row0 col0" >2842</td>
#       <td id="T_02ddd_row0_col1" class="data row0 col1" >16</td>
#     </tr>
#   </tbody>
# </table>
# Exiting summary display...

# %% [markdown]
# ## Step 6: Processing and Visualizing Data
#
# With data now being consumed, let’s set up a processor to organize and analyze the stream for easy viewing and plotting.

# %%
# Set up the data processor
processor = SageDataProcessing(consumer)

# %% [markdown]
# #### Real-Time Temperature Alerts
#
# We can now plot temperature data in real time, with alerts highlighting any critical conditions across states.

# %%
await plot_temp_alerts(processor)
# Out:
# FigureWidget({
#     'data': [{'hoverinfo': 'text',
#               'marker': {'color': 'red', 'size': 10, 'symbol': 'circle'},
#               'mode': 'markers',
#               'name': 'Alert',
#               'showlegend': True,
#               'text': [Heatwave, Heatwave, Heatwave, Heatwave, Heatwave, Heatwave,
#                        Heatwave, Heatwave, Heatwave, Heatwave, Heatwave, Heatwave,
#                        Heatwave, Heatwave, Heatwave, Heatwave, Heatwave, Heatwave,
#                        Heatwave, Heatwave, Heatwave, Heatwave, Heatwave, Heatwave,
#                        Heatwave, Heatwave, Heatwave, Heatwave, Heatwave, Heatwave,
#                        Heatwave, Heatwave, Heatwave, Heatwave, Heatwave, Heatwave,
#                        Heatwave, Heatwave, Heatwave, Heatwave, Heatwave, Heatwave,
#                        Heatwave, Heatwave, Heatwave, Heatwave, Heatwave, Heatwave,
#                        Heatwave, Heatwave, Heatwave, Heatwave, Heatwave, Heatwave,
#                        Heatwave, Heatwave, Heatwave, Heatwave, Heatwave, Heatwave,
#                        Heatwave, Heatwave, Heatwave, Heatwave, Heatwave, Heatwave,
#                        Heatwave, Heatwave, Heatwave, Heatwave, Heatwave, Heatwave,
#                        Heatwave, Heatwave, Heatwave, Heatwave, Heatwave, Heatwave,
#                        Heatwave, Heatwave, Heatwave, Heatwave, Heatwave, Heatwave,
#                        Heatwave, Heatwave, Heatwave, Heatwave, Heatwave, Heatwave,
#                        Heatwave, Heatwave, Heatwave, Heatwave, Heatwave, Heatwave,
#                        Heatwave, Heatwave, Heatwave, Heatwave, Heatwave, Heatwave,
#                        Heatwave, Heatwave, Heatwave, Heatwave, Heatwave, Heatwave,
#                        Heatwave, Heatwave, Heatwave, Heatwave, Heatwave, Heatwave,
#                        Heatwave, Heatwave, Heatwave, Heatwave],
#               'type': 'scatter',
#               'uid': '25ef952a-6f5b-4da6-95a2-d150afc1ed94',
#               'x': [2024-11-12 19:35:20+00:00, 2024-11-12 19:35:50+00:00,
#                     2024-11-12 19:36:20+00:00, 2024-11-12 19:36:50+00:00,
#                     2024-11-12 19:37:20+00:00, 2024-11-12 19:37:50+00:00,
#                     2024-11-12 19:38:20+00:00, 2024-11-12 19:38:50+00:00,
#                     2024-11-12 19:39:20+00:00, 2024-11-12 19:39:50+00:00,
#                     2024-11-12 19:40:20+00:00, 2024-11-12 19:40:50+00:00,
#                     2024-11-12 19:41:20+00:00, 2024-11-12 19:41:50+00:00,
#                     2024-11-12 19:42:20+00:00, 2024-11-12 19:42:50+00:00,
#                     2024-11-12 19:43:20+00:00, 2024-11-12 19:43:50+00:00,
#                     2024-11-12 19:44:20+00:00, 2024-11-12 19:44:50+00:00,
#                     2024-11-12 19:45:50+00:00, 2024-11-12 19:46:20+00:00,
#                     2024-11-12 19:46:50+00:00, 2024-11-12 19:47:20+00:00,
#                     2024-11-12 19:47:50+00:00, 2024-11-12 19:48:20+00:00,
#                     2024-11-12 19:48:50+00:00, 2024-11-12 19:49:20+00:00,
#                     2024-11-12 19:49:50+00:00, 2024-11-12 19:35:24+00:00,
#                     2024-11-12 19:35:54+00:00, 2024-11-12 19:36:24+00:00,
#                     2024-11-12 19:36:54+00:00, 2024-11-12 19:37:24+00:00,
#                     2024-11-12 19:37:54+00:00, 2024-11-12 19:38:24+00:00,
#                     2024-11-12 19:38:54+00:00, 2024-11-12 19:39:24+00:00,
#                     2024-11-12 19:39:54+00:00, 2024-11-12 19:40:24+00:00,
#                     2024-11-12 19:40:54+00:00, 2024-11-12 19:41:24+00:00,
#                     2024-11-12 19:41:54+00:00, 2024-11-12 19:42:24+00:00,
#                     2024-11-12 19:42:54+00:00, 2024-11-12 19:43:24+00:00,
#                     2024-11-12 19:43:54+00:00, 2024-11-12 19:44:24+00:00,
#                     2024-11-12 19:44:54+00:00, 2024-11-12 19:45:24+00:00,
#                     2024-11-12 19:45:54+00:00, 2024-11-12 19:46:24+00:00,
#                     2024-11-12 19:46:54+00:00, 2024-11-12 19:47:24+00:00,
#                     2024-11-12 19:47:54+00:00, 2024-11-12 19:48:24+00:00,
#                     2024-11-12 19:48:54+00:00, 2024-11-12 19:49:24+00:00,
#                     2024-11-12 19:49:54+00:00, 2024-11-12 19:35:14+00:00,
#                     2024-11-12 19:35:44+00:00, 2024-11-12 19:36:14+00:00,
#                     2024-11-12 19:36:44+00:00, 2024-11-12 19:37:14+00:00,
#                     2024-11-12 19:37:44+00:00, 2024-11-12 19:38:14+00:00,
#                     2024-11-12 19:38:44+00:00, 2024-11-12 19:39:14+00:00,
#                     2024-11-12 19:39:44+00:00, 2024-11-12 19:40:44+00:00,
#                     2024-11-12 19:41:14+00:00, 2024-11-12 19:41:44+00:00,
#                     2024-11-12 19:42:14+00:00, 2024-11-12 19:42:44+00:00,
#                     2024-11-12 19:43:14+00:00, 2024-11-12 19:43:44+00:00,
#                     2024-11-12 19:44:14+00:00, 2024-11-12 19:44:44+00:00,
#                     2024-11-12 19:45:44+00:00, 2024-11-12 19:46:14+00:00,
#                     2024-11-12 19:46:44+00:00, 2024-11-12 19:47:14+00:00,
#                     2024-11-12 19:47:44+00:00, 2024-11-12 19:48:14+00:00,
#                     2024-11-12 19:48:44+00:00, 2024-11-12 19:49:14+00:00,
#                     2024-11-12 19:49:44+00:00, 2024-11-12 19:50:14+00:00,
#                     2024-11-12 19:35:24+00:00, 2024-11-12 19:35:54+00:00,
#                     2024-11-12 19:36:24+00:00, 2024-11-12 19:36:54+00:00,
#                     2024-11-12 19:37:24+00:00, 2024-11-12 19:37:54+00:00,
#                     2024-11-12 19:38:24+00:00, 2024-11-12 19:38:54+00:00,
#                     2024-11-12 19:39:24+00:00, 2024-11-12 19:39:54+00:00,
#                     2024-11-12 19:40:24+00:00, 2024-11-12 19:40:54+00:00,
#                     2024-11-12 19:41:24+00:00, 2024-11-12 19:41:54+00:00,
#                     2024-11-12 19:42:24+00:00, 2024-11-12 19:42:54+00:00,
#                     2024-11-12 19:43:24+00:00, 2024-11-12 19:43:54+00:00,
#                     2024-11-12 19:44:24+00:00, 2024-11-12 19:44:54+00:00,
#                     2024-11-12 19:45:24+00:00, 2024-11-12 19:45:54+00:00,
#                     2024-11-12 19:46:24+00:00, 2024-11-12 19:46:54+00:00,
#                     2024-11-12 19:47:24+00:00, 2024-11-12 19:47:54+00:00,
#                     2024-11-12 19:48:24+00:00, 2024-11-12 19:48:54+00:00,
#                     2024-11-12 19:49:24+00:00, 2024-11-12 19:49:54+00:00],
#               'y': [34.93, 34.95, 34.92, 34.94, 34.92, 34.93, 34.95, 34.95, 34.95,
#                     34.95, 34.98, 34.96, 34.97, 34.96, 34.97, 34.97, 34.96, 34.97,
#                     34.97, 34.95, 35.02, 35.02, 35.03, 35.02, 35.05, 35.01, 35.01,
#                     35.0, 35.0, 23.19, 23.19, 23.17, 23.16, 23.16, 23.14, 23.13,
#                     23.11, 23.12, 23.11, 23.13, 23.11, 23.12, 23.13, 23.12,
#                     23.109999999999996, 23.13, 23.12, 23.13, 23.13, 23.13, 23.12,
#                     23.11, 23.11, 23.12, 23.13, 23.13, 23.13, 23.14, 23.16, 24.52,
#                     24.51, 24.48, 24.45, 24.41, 24.37, 24.32, 24.28,
#                     24.259999999999998, 24.21, 24.180000000000003, 24.18, 24.18,
#                     24.18, 24.19, 24.18, 24.17, 24.149999999999995, 24.14, 24.12,
#                     24.09, 24.09, 24.08, 24.05, 24.06, 24.04, 24.05, 24.06, 24.07,
#                     29.87, 29.89, 29.91, 29.88, 29.88, 29.87, 29.88, 29.88, 29.87,
#                     29.85, 29.829999999999995, 29.82, 29.8, 29.77, 29.79, 29.75,
#                     29.73, 29.69, 29.679999999999996, 29.66, 29.630000000000003,
#                     29.63, 29.600000000000005, 29.59, 29.57, 29.6, 29.59, 29.61,
#                     29.61, 29.6]},
#              {'line': {'color': 'hsl(30, 70%, 50%)'},
#               'marker': {'size': 4, 'symbol': 'circle'},
#               'mode': 'lines+markers',
#               'name': 'California',
#               'type': 'scatter',
#               'uid': '7143cec6-1bcd-43d9-a755-874c40ccc3e9',
#               'x': array([datetime.datetime(2024, 11, 12, 19, 35, 20, tzinfo=datetime.timezone.utc),
#                           datetime.datetime(2024, 11, 12, 19, 35, 50, tzinfo=datetime.timezone.utc),
#                           datetime.datetime(2024, 11, 12, 19, 36, 20, tzinfo=datetime.timezone.utc),
#                           datetime.datetime(2024, 11, 12, 19, 36, 50, tzinfo=datetime.timezone.utc),
#                           datetime.datetime(2024, 11, 12, 19, 37, 20, tzinfo=datetime.timezone.utc),
#                           datetime.datetime(2024, 11, 12, 19, 37, 50, tzinfo=datetime.timezone.utc),
#                           datetime.datetime(2024, 11, 12, 19, 38, 20, tzinfo=datetime.timezone.utc),
#                           datetime.datetime(2024, 11, 12, 19, 38, 50, tzinfo=datetime.timezone.utc),
#                           datetime.datetime(2024, 11, 12, 19, 39, 20, tzinfo=datetime.timezone.utc),
#                           datetime.datetime(2024, 11, 12, 19, 39, 50, tzinfo=datetime.timezone.utc),
#                           datetime.datetime(2024, 11, 12, 19, 40, 20, tzinfo=datetime.timezone.utc),
#                           datetime.datetime(2024, 11, 12, 19, 40, 50, tzinfo=datetime.timezone.utc),
#                           datetime.datetime(2024, 11, 12, 19, 41, 20, tzinfo=datetime.timezone.utc),
#                           datetime.datetime(2024, 11, 12, 19, 41, 50, tzinfo=datetime.timezone.utc),
#                           datetime.datetime(2024, 11, 12, 19, 42, 20, tzinfo=datetime.timezone.utc),
#                           datetime.datetime(2024, 11, 12, 19, 42, 50, tzinfo=datetime.timezone.utc),
#                           datetime.datetime(2024, 11, 12, 19, 43, 20, tzinfo=datetime.timezone.utc),
#                           datetime.datetime(2024, 11, 12, 19, 43, 50, tzinfo=datetime.timezone.utc),
#                           datetime.datetime(2024, 11, 12, 19, 44, 20, tzinfo=datetime.timezone.utc),
#                           datetime.datetime(2024, 11, 12, 19, 44, 50, tzinfo=datetime.timezone.utc),
#                           datetime.datetime(2024, 11, 12, 19, 45, 50, tzinfo=datetime.timezone.utc),
#                           datetime.datetime(2024, 11, 12, 19, 46, 20, tzinfo=datetime.timezone.utc),
#                           datetime.datetime(2024, 11, 12, 19, 46, 50, tzinfo=datetime.timezone.utc),
#                           datetime.datetime(2024, 11, 12, 19, 47, 20, tzinfo=datetime.timezone.utc),
#                           datetime.datetime(2024, 11, 12, 19, 47, 50, tzinfo=datetime.timezone.utc),
#                           datetime.datetime(2024, 11, 12, 19, 48, 20, tzinfo=datetime.timezone.utc),
#                           datetime.datetime(2024, 11, 12, 19, 48, 50, tzinfo=datetime.timezone.utc),
#                           datetime.datetime(2024, 11, 12, 19, 49, 20, tzinfo=datetime.timezone.utc),
#                           datetime.datetime(2024, 11, 12, 19, 49, 50, tzinfo=datetime.timezone.utc),
#                           datetime.datetime(2024, 11, 12, 19, 50, 20, tzinfo=datetime.timezone.utc)],
#                          dtype=object),
#               'y': array([34.93, 34.95, 34.92, 34.94, 34.92, 34.93, 34.95, 34.95, 34.95, 34.95,
#                           34.98, 34.96, 34.97, 34.96, 34.97, 34.97, 34.96, 34.97, 34.97, 34.95,
#                           35.02, 35.02, 35.03, 35.02, 35.05, 35.01, 35.01, 35.  , 35.  , 35.  ])},
#              {'line': {'color': 'hsl(66, 70%, 50%)'},
#               'marker': {'size': 4, 'symbol': 'circle'},
#               'mode': 'lines+markers',
#               'name': 'Illinois',
#               'type': 'scatter',
#               'uid': 'baacc167-e488-43b1-b0e5-cc12f7fd1cc6',
#               'x': array([datetime.datetime(2024, 11, 12, 19, 35, 20, tzinfo=datetime.timezone.utc),
#                           datetime.datetime(2024, 11, 12, 19, 35, 50, tzinfo=datetime.timezone.utc),
#                           datetime.datetime(2024, 11, 12, 19, 36, 20, tzinfo=datetime.timezone.utc),
#                           datetime.datetime(2024, 11, 12, 19, 36, 50, tzinfo=datetime.timezone.utc),
#                           datetime.datetime(2024, 11, 12, 19, 37, 20, tzinfo=datetime.timezone.utc),
#                           datetime.datetime(2024, 11, 12, 19, 37, 50, tzinfo=datetime.timezone.utc),
#                           datetime.datetime(2024, 11, 12, 19, 38, 20, tzinfo=datetime.timezone.utc),
#                           datetime.datetime(2024, 11, 12, 19, 38, 50, tzinfo=datetime.timezone.utc),
#                           datetime.datetime(2024, 11, 12, 19, 39, 20, tzinfo=datetime.timezone.utc),
#                           datetime.datetime(2024, 11, 12, 19, 39, 50, tzinfo=datetime.timezone.utc),
#                           datetime.datetime(2024, 11, 12, 19, 40, 20, tzinfo=datetime.timezone.utc),
#                           datetime.datetime(2024, 11, 12, 19, 40, 50, tzinfo=datetime.timezone.utc),
#                           datetime.datetime(2024, 11, 12, 19, 41, 20, tzinfo=datetime.timezone.utc),
#                           datetime.datetime(2024, 11, 12, 19, 41, 50, tzinfo=datetime.timezone.utc),
#                           datetime.datetime(2024, 11, 12, 19, 42, 20, tzinfo=datetime.timezone.utc),
#                           datetime.datetime(2024, 11, 12, 19, 42, 58, tzinfo=datetime.timezone.utc),
#                           datetime.datetime(2024, 11, 12, 19, 43, 24, tzinfo=datetime.timezone.utc),
#                           datetime.datetime(2024, 11, 12, 19, 43, 56, tzinfo=datetime.timezone.utc),
#                           datetime.datetime(2024, 11, 12, 19, 44, 26, tzinfo=datetime.timezone.utc),
#                           datetime.datetime(2024, 11, 12, 19, 45, tzinfo=datetime.timezone.utc),
#                           datetime.datetime(2024, 11, 12, 19, 45, 28, tzinfo=datetime.timezone.utc),
#                           datetime.datetime(2024, 11, 12, 19, 45, 56, tzinfo=datetime.timezone.utc),
#                           datetime.datetime(2024, 11, 12, 19, 46, 26, tzinfo=datetime.timezone.utc),
#                           datetime.datetime(2024, 11, 12, 19, 46, 56, tzinfo=datetime.timezone.utc),
#                           datetime.datetime(2024, 11, 12, 19, 47, 30, tzinfo=datetime.timezone.utc),
#                           datetime.datetime(2024, 11, 12, 19, 47, 58, tzinfo=datetime.timezone.utc),
#                           datetime.datetime(2024, 11, 12, 19, 48, 28, tzinfo=datetime.timezone.utc),
#                           datetime.datetime(2024, 11, 12, 19, 49, tzinfo=datetime.timezone.utc),
#                           datetime.datetime(2024, 11, 12, 19, 49, 30, tzinfo=datetime.timezone.utc),
#                           datetime.datetime(2024, 11, 12, 19, 50, tzinfo=datetime.timezone.utc),
#                           datetime.datetime(2024, 11, 12, 19, 50, 30, tzinfo=datetime.timezone.utc)],
#                          dtype=object),
#               'y': array([25.32, 25.33, 25.33, 25.34, 25.34, 25.36, 25.36, 25.37, 25.37, 25.35,
#                           25.34, 25.32, 25.31, 25.32, 25.31, 25.3 , 25.29, 25.31, 25.31, 25.31,
#                           25.32, 25.32, 25.3 , 25.3 , 25.29, 25.28, 25.27, 25.27, 25.26, 25.25,
#                           25.24])},
#              {'line': {'color': 'hsl(102, 70%, 50%)'},
#               'marker': {'size': 4, 'symbol': 'circle'},
#               'mode': 'lines+markers',
#               'name': 'Michigan',
#               'type': 'scatter',
#               'uid': 'ada4d932-a401-4fd1-b37d-92fea778331e',
#               'x': array([datetime.datetime(2024, 11, 12, 19, 35, 24, tzinfo=datetime.timezone.utc),
#                           datetime.datetime(2024, 11, 12, 19, 35, 54, tzinfo=datetime.timezone.utc),
#                           datetime.datetime(2024, 11, 12, 19, 36, 24, tzinfo=datetime.timezone.utc),
#                           datetime.datetime(2024, 11, 12, 19, 36, 54, tzinfo=datetime.timezone.utc),
#                           datetime.datetime(2024, 11, 12, 19, 37, 24, tzinfo=datetime.timezone.utc),
#                           datetime.datetime(2024, 11, 12, 19, 37, 54, tzinfo=datetime.timezone.utc),
#                           datetime.datetime(2024, 11, 12, 19, 38, 24, tzinfo=datetime.timezone.utc),
#                           datetime.datetime(2024, 11, 12, 19, 38, 54, tzinfo=datetime.timezone.utc),
#                           datetime.datetime(2024, 11, 12, 19, 39, 24, tzinfo=datetime.timezone.utc),
#                           datetime.datetime(2024, 11, 12, 19, 39, 54, tzinfo=datetime.timezone.utc),
#                           datetime.datetime(2024, 11, 12, 19, 40, 24, tzinfo=datetime.timezone.utc),
#                           datetime.datetime(2024, 11, 12, 19, 40, 54, tzinfo=datetime.timezone.utc),
#                           datetime.datetime(2024, 11, 12, 19, 41, 24, tzinfo=datetime.timezone.utc),
#                           datetime.datetime(2024, 11, 12, 19, 41, 54, tzinfo=datetime.timezone.utc),
#                           datetime.datetime(2024, 11, 12, 19, 42, 24, tzinfo=datetime.timezone.utc),
#                           datetime.datetime(2024, 11, 12, 19, 42, 54, tzinfo=datetime.timezone.utc),
#                           datetime.datetime(2024, 11, 12, 19, 43, 24, tzinfo=datetime.timezone.utc),
#                           datetime.datetime(2024, 11, 12, 19, 43, 54, tzinfo=datetime.timezone.utc),
#                           datetime.datetime(2024, 11, 12, 19, 44, 24, tzinfo=datetime.timezone.utc),
#                           datetime.datetime(2024, 11, 12, 19, 44, 54, tzinfo=datetime.timezone.utc),
#                           datetime.datetime(2024, 11, 12, 19, 45, 24, tzinfo=datetime.timezone.utc),
#                           datetime.datetime(2024, 11, 12, 19, 45, 54, tzinfo=datetime.timezone.utc),
#                           datetime.datetime(2024, 11, 12, 19, 46, 24, tzinfo=datetime.timezone.utc),
#                           datetime.datetime(2024, 11, 12, 19, 46, 54, tzinfo=datetime.timezone.utc),
#                           datetime.datetime(2024, 11, 12, 19, 47, 24, tzinfo=datetime.timezone.utc),
#                           datetime.datetime(2024, 11, 12, 19, 47, 54, tzinfo=datetime.timezone.utc),
#                           datetime.datetime(2024, 11, 12, 19, 48, 24, tzinfo=datetime.timezone.utc),
#                           datetime.datetime(2024, 11, 12, 19, 48, 54, tzinfo=datetime.timezone.utc),
#                           datetime.datetime(2024, 11, 12, 19, 49, 24, tzinfo=datetime.timezone.utc),
#                           datetime.datetime(2024, 11, 12, 19, 49, 54, tzinfo=datetime.timezone.utc)],
#                          dtype=object),
#               'y': array([23.19, 23.19, 23.17, 23.16, 23.16, 23.14, 23.13, 23.11, 23.12, 23.11,
#                           23.13, 23.11, 23.12, 23.13, 23.12, 23.11, 23.13, 23.12, 23.13, 23.13,
#                           23.13, 23.12, 23.11, 23.11, 23.12, 23.13, 23.13, 23.13, 23.14, 23.16])},
#              {'line': {'color': 'hsl(138, 70%, 50%)'},
#               'marker': {'size': 4, 'symbol': 'circle'},
#               'mode': 'lines+markers',
#               'name': 'Montana',
#               'type': 'scatter',
#               'uid': '2cb39766-f73a-4925-b216-20acddcb2e0c',
#               'x': array([datetime.datetime(2024, 11, 12, 19, 35, 14, tzinfo=datetime.timezone.utc),
#                           datetime.datetime(2024, 11, 12, 19, 35, 44, tzinfo=datetime.timezone.utc),
#                           datetime.datetime(2024, 11, 12, 19, 36, 14, tzinfo=datetime.timezone.utc),
#                           datetime.datetime(2024, 11, 12, 19, 36, 44, tzinfo=datetime.timezone.utc),
#                           datetime.datetime(2024, 11, 12, 19, 37, 14, tzinfo=datetime.timezone.utc),
#                           datetime.datetime(2024, 11, 12, 19, 37, 44, tzinfo=datetime.timezone.utc),
#                           datetime.datetime(2024, 11, 12, 19, 38, 14, tzinfo=datetime.timezone.utc),
#                           datetime.datetime(2024, 11, 12, 19, 38, 44, tzinfo=datetime.timezone.utc),
#                           datetime.datetime(2024, 11, 12, 19, 39, 14, tzinfo=datetime.timezone.utc),
#                           datetime.datetime(2024, 11, 12, 19, 39, 44, tzinfo=datetime.timezone.utc),
#                           datetime.datetime(2024, 11, 12, 19, 40, 44, tzinfo=datetime.timezone.utc),
#                           datetime.datetime(2024, 11, 12, 19, 41, 14, tzinfo=datetime.timezone.utc),
#                           datetime.datetime(2024, 11, 12, 19, 41, 44, tzinfo=datetime.timezone.utc),
#                           datetime.datetime(2024, 11, 12, 19, 42, 14, tzinfo=datetime.timezone.utc),
#                           datetime.datetime(2024, 11, 12, 19, 42, 44, tzinfo=datetime.timezone.utc),
#                           datetime.datetime(2024, 11, 12, 19, 43, 14, tzinfo=datetime.timezone.utc),
#                           datetime.datetime(2024, 11, 12, 19, 43, 44, tzinfo=datetime.timezone.utc),
#                           datetime.datetime(2024, 11, 12, 19, 44, 14, tzinfo=datetime.timezone.utc),
#                           datetime.datetime(2024, 11, 12, 19, 44, 44, tzinfo=datetime.timezone.utc),
#                           datetime.datetime(2024, 11, 12, 19, 45, 44, tzinfo=datetime.timezone.utc),
#                           datetime.datetime(2024, 11, 12, 19, 46, 14, tzinfo=datetime.timezone.utc),
#                           datetime.datetime(2024, 11, 12, 19, 46, 44, tzinfo=datetime.timezone.utc),
#                           datetime.datetime(2024, 11, 12, 19, 47, 14, tzinfo=datetime.timezone.utc),
#                           datetime.datetime(2024, 11, 12, 19, 47, 44, tzinfo=datetime.timezone.utc),
#                           datetime.datetime(2024, 11, 12, 19, 48, 14, tzinfo=datetime.timezone.utc),
#                           datetime.datetime(2024, 11, 12, 19, 48, 44, tzinfo=datetime.timezone.utc),
#                           datetime.datetime(2024, 11, 12, 19, 49, 14, tzinfo=datetime.timezone.utc),
#                           datetime.datetime(2024, 11, 12, 19, 49, 44, tzinfo=datetime.timezone.utc),
#                           datetime.datetime(2024, 11, 12, 19, 50, 14, tzinfo=datetime.timezone.utc)],
#                          dtype=object),
#               'y': array([24.52, 24.51, 24.48, 24.45, 24.41, 24.37, 24.32, 24.28, 24.26, 24.21,
#                           24.18, 24.18, 24.18, 24.18, 24.19, 24.18, 24.17, 24.15, 24.14, 24.12,
#                           24.09, 24.09, 24.08, 24.05, 24.06, 24.04, 24.05, 24.06, 24.07])},
#              {'line': {'color': 'hsl(174, 70%, 50%)'},
#               'marker': {'size': 4, 'symbol': 'circle'},
#               'mode': 'lines+markers',
#               'name': 'North Dakota',
#               'type': 'scatter',
#               'uid': '93ef847f-1768-4196-bfd8-aa83cb208d34',
#               'x': array([datetime.datetime(2024, 11, 12, 19, 35, 24, tzinfo=datetime.timezone.utc),
#                           datetime.datetime(2024, 11, 12, 19, 35, 54, tzinfo=datetime.timezone.utc),
#                           datetime.datetime(2024, 11, 12, 19, 36, 24, tzinfo=datetime.timezone.utc),
#                           datetime.datetime(2024, 11, 12, 19, 36, 54, tzinfo=datetime.timezone.utc),
#                           datetime.datetime(2024, 11, 12, 19, 37, 24, tzinfo=datetime.timezone.utc),
#                           datetime.datetime(2024, 11, 12, 19, 37, 54, tzinfo=datetime.timezone.utc),
#                           datetime.datetime(2024, 11, 12, 19, 38, 24, tzinfo=datetime.timezone.utc),
#                           datetime.datetime(2024, 11, 12, 19, 38, 54, tzinfo=datetime.timezone.utc),
#                           datetime.datetime(2024, 11, 12, 19, 39, 24, tzinfo=datetime.timezone.utc),
#                           datetime.datetime(2024, 11, 12, 19, 39, 54, tzinfo=datetime.timezone.utc),
#                           datetime.datetime(2024, 11, 12, 19, 40, 24, tzinfo=datetime.timezone.utc),
#                           datetime.datetime(2024, 11, 12, 19, 40, 54, tzinfo=datetime.timezone.utc),
#                           datetime.datetime(2024, 11, 12, 19, 41, 24, tzinfo=datetime.timezone.utc),
#                           datetime.datetime(2024, 11, 12, 19, 41, 54, tzinfo=datetime.timezone.utc),
#                           datetime.datetime(2024, 11, 12, 19, 42, 24, tzinfo=datetime.timezone.utc),
#                           datetime.datetime(2024, 11, 12, 19, 42, 54, tzinfo=datetime.timezone.utc),
#                           datetime.datetime(2024, 11, 12, 19, 43, 24, tzinfo=datetime.timezone.utc),
#                           datetime.datetime(2024, 11, 12, 19, 43, 54, tzinfo=datetime.timezone.utc),
#                           datetime.datetime(2024, 11, 12, 19, 44, 24, tzinfo=datetime.timezone.utc),
#                           datetime.datetime(2024, 11, 12, 19, 44, 54, tzinfo=datetime.timezone.utc),
#                           datetime.datetime(2024, 11, 12, 19, 45, 24, tzinfo=datetime.timezone.utc),
#                           datetime.datetime(2024, 11, 12, 19, 45, 54, tzinfo=datetime.timezone.utc),
#                           datetime.datetime(2024, 11, 12, 19, 46, 24, tzinfo=datetime.timezone.utc),
#                           datetime.datetime(2024, 11, 12, 19, 46, 54, tzinfo=datetime.timezone.utc),
#                           datetime.datetime(2024, 11, 12, 19, 47, 24, tzinfo=datetime.timezone.utc),
#                           datetime.datetime(2024, 11, 12, 19, 47, 54, tzinfo=datetime.timezone.utc),
#                           datetime.datetime(2024, 11, 12, 19, 48, 24, tzinfo=datetime.timezone.utc),
#                           datetime.datetime(2024, 11, 12, 19, 48, 54, tzinfo=datetime.timezone.utc),
#                           datetime.datetime(2024, 11, 12, 19, 49, 24, tzinfo=datetime.timezone.utc),
#                           datetime.datetime(2024, 11, 12, 19, 49, 54, tzinfo=datetime.timezone.utc)],
#                          dtype=object),
#               'y': array([29.87, 29.89, 29.91, 29.88, 29.88, 29.87, 29.88, 29.88, 29.87, 29.85,
#                           29.83, 29.82, 29.8 , 29.77, 29.79, 29.75, 29.73, 29.69, 29.68, 29.66,
#                           29.63, 29.63, 29.6 , 29.59, 29.57, 29.6 , 29.59, 29.61, 29.61, 29.6 ])},
#              {'line': {'color': 'hsl(210, 70%, 50%)'},
#               'marker': {'size': 4, 'symbol': 'circle'},
#               'mode': 'lines+markers',
#               'name': 'Oregon',
#               'type': 'scatter',
#               'uid': 'f9b05875-4a98-4ba2-8481-1af419de8ead',
#               'x': array([datetime.datetime(2024, 11, 12, 19, 35, 24, tzinfo=datetime.timezone.utc),
#                           datetime.datetime(2024, 11, 12, 19, 35, 54, tzinfo=datetime.timezone.utc),
#                           datetime.datetime(2024, 11, 12, 19, 36, 24, tzinfo=datetime.timezone.utc),
#                           datetime.datetime(2024, 11, 12, 19, 36, 54, tzinfo=datetime.timezone.utc),
#                           datetime.datetime(2024, 11, 12, 19, 37, 24, tzinfo=datetime.timezone.utc),
#                           datetime.datetime(2024, 11, 12, 19, 37, 54, tzinfo=datetime.timezone.utc),
#                           datetime.datetime(2024, 11, 12, 19, 38, 24, tzinfo=datetime.timezone.utc),
#                           datetime.datetime(2024, 11, 12, 19, 38, 54, tzinfo=datetime.timezone.utc),
#                           datetime.datetime(2024, 11, 12, 19, 39, 24, tzinfo=datetime.timezone.utc),
#                           datetime.datetime(2024, 11, 12, 19, 39, 54, tzinfo=datetime.timezone.utc),
#                           datetime.datetime(2024, 11, 12, 19, 40, 24, tzinfo=datetime.timezone.utc),
#                           datetime.datetime(2024, 11, 12, 19, 40, 54, tzinfo=datetime.timezone.utc),
#                           datetime.datetime(2024, 11, 12, 19, 41, 24, tzinfo=datetime.timezone.utc),
#                           datetime.datetime(2024, 11, 12, 19, 41, 54, tzinfo=datetime.timezone.utc),
#                           datetime.datetime(2024, 11, 12, 19, 42, 24, tzinfo=datetime.timezone.utc),
#                           datetime.datetime(2024, 11, 12, 19, 42, 54, tzinfo=datetime.timezone.utc),
#                           datetime.datetime(2024, 11, 12, 19, 43, 24, tzinfo=datetime.timezone.utc),
#                           datetime.datetime(2024, 11, 12, 19, 43, 54, tzinfo=datetime.timezone.utc),
#                           datetime.datetime(2024, 11, 12, 19, 44, 24, tzinfo=datetime.timezone.utc),
#                           datetime.datetime(2024, 11, 12, 19, 44, 54, tzinfo=datetime.timezone.utc),
#                           datetime.datetime(2024, 11, 12, 19, 45, 24, tzinfo=datetime.timezone.utc),
#                           datetime.datetime(2024, 11, 12, 19, 45, 54, tzinfo=datetime.timezone.utc),
#                           datetime.datetime(2024, 11, 12, 19, 46, 24, tzinfo=datetime.timezone.utc),
#                           datetime.datetime(2024, 11, 12, 19, 46, 54, tzinfo=datetime.timezone.utc),
#                           datetime.datetime(2024, 11, 12, 19, 47, 24, tzinfo=datetime.timezone.utc),
#                           datetime.datetime(2024, 11, 12, 19, 47, 54, tzinfo=datetime.timezone.utc),
#                           datetime.datetime(2024, 11, 12, 19, 48, 24, tzinfo=datetime.timezone.utc),
#                           datetime.datetime(2024, 11, 12, 19, 48, 54, tzinfo=datetime.timezone.utc),
#                           datetime.datetime(2024, 11, 12, 19, 49, 24, tzinfo=datetime.timezone.utc),
#                           datetime.datetime(2024, 11, 12, 19, 49, 54, tzinfo=datetime.timezone.utc)],
#                          dtype=object),
#               'y': array([23.41, 23.41, 23.41, 23.39, 23.4 , 23.4 , 23.38, 23.38, 23.37, 23.35,
#                           23.34, 23.32, 23.3 , 23.26, 23.24, 23.21, 23.19, 23.18, 23.15, 23.12,
#                           23.11, 23.08, 23.06, 23.04, 23.02, 23.  , 22.99, 22.99, 22.98, 22.99])}],
#     'layout': {'autosize': True,
#                'margin': {'b': 50, 'l': 50, 'r': 50, 't': 50},
#                'template': '...',
#                'title': {'text': 'Real-Time Temperature Data by State'},
#                'xaxis': {'tickformat': '%H:%M:%S', 'title': {'text': 'Timestamp'}},
#                'yaxis': {'range': [17.98, 40.05], 'title': {'text': 'Temperature (°C)'}}}
# })
# Last 10 Alerts:
# At 19:45:24, Heatwave alert in North Dakota.
# At 19:45:54, Heatwave alert in North Dakota.
# At 19:46:24, Heatwave alert in North Dakota.
# At 19:46:54, Heatwave alert in North Dakota.
# At 19:47:24, Heatwave alert in North Dakota.
# At 19:47:54, Heatwave alert in North Dakota.
# At 19:48:24, Heatwave alert in North Dakota.
# At 19:48:54, Heatwave alert in North Dakota.
# At 19:49:24, Heatwave alert in North Dakota.
# At 19:49:54, Heatwave alert in North Dakota.
# Visualization stopped.

# %% [markdown]
# ### Viewing Processed Data
#
# Let’s view the latest 5 rows of the processed and aggregated data to see a snapshot of our current data.

# %%
processor.get_aggregated_df().tail(5)
# Out:
#                     timestamp         state     alert  temperature  humidity  \
# 185 2024-11-12 19:50:50+00:00    California  Heatwave        35.05     8.130
# 186 2024-11-12 19:50:54+00:00      Michigan  Heatwave        23.17    17.726
# 187 2024-11-12 19:50:54+00:00  North Dakota  Heatwave        29.60    15.336
# 188 2024-11-12 19:50:54+00:00        Oregon      None        22.97    49.745
# 189 2024-11-12 19:51:00+00:00      Illinois      None        25.24    25.698
#
#           pressure
# 185   83145.039062
# 186   95903.000000
# 187   97771.886718
# 188  100145.039062
# 189  100755.875000

# %% [markdown]
# ## Step 7: Stopping Data Consumption and Processing
#
# To wrap up, we’ll stop the data consumer and processor, ending the data flow and background tasks.

# %%
# Stop the data consumer and processor
processor.stop()
consumer.stop()

# %% [markdown]
# #### Cleaning Up Resources
#
# Finally, we’ll delete the registered entries for the SAGE sensors to free up resources on the sciDX platform. This cleanup ensures that no unused resources remain after this tutorial.

# %%
# Get the resource IDs from the search results
resource_ids = [result['id'] for result in search_results]

# Delete both resources using the sciDXClient's delete_resource method
for resource_id in resource_ids:
    delete_response = client.delete_resource(resource_id)
    print(f"Deleted resource {resource_id}: {delete_response}")
# Out:
# Deleted resource 3354de76-4fc4-48fb-bc8e-1f462d823d70: {'message': '3354de76-4fc4-48fb-bc8e-1f462d823d70 deleted successfully'}
# Deleted resource 6e5eb6e0-7050-4610-9257-302566316696: {'message': '6e5eb6e0-7050-4610-9257-302566316696 deleted successfully'}
# Deleted resource 9aebd5f8-8dc4-49fb-b380-eb7536dcbb13: {'message': '9aebd5f8-8dc4-49fb-b380-eb7536dcbb13 deleted successfully'}
